# %%
from scripts.simulation_imports import *
import os

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define x-axis values
x = [300, 500, 1000, 2000, 50000]

# Define y-axis values
slateq = [0.064939, 0.110338, 0.229349, 0.448962, 1.150223]
wa_5 = [0.004210, 0.006127, 0.011299, 0.042985, 0.093208]
wa_10 = [0.007421, 0.011449, 0.023207, 0.086088, 0.180334]
wa_20 = [0.013384, 0.021687, 0.061213, 0.159714, 0.289025]

# Set the width of the bars
bar_width = 0.2

# Set the positions of the bars on the x-axis
r1 = np.arange(len(slateq))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Create the bar plot
plt.bar(r1, slateq, color='red', width=bar_width, edgecolor='black', label='Slateq')
plt.bar(r2, wa_5, color='green', width=bar_width, edgecolor='black', label='Wa_5')
plt.bar(r3, wa_10, color='blue', width=bar_width, edgecolor='black', label='Wa_10')
plt.bar(r4, wa_20, color='orange', width=bar_width, edgecolor='black', label='Wa_20')

# Add x-axis ticks and labels
plt.xticks([r + bar_width for r in range(len(slateq))], x)

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Define x-axis values
x = [300, 500, 1000, 2000, 50000]

# Define y-axis values
wa_5 = [0.004210, 0.006127, 0.011299, 0.042985, 0.093208]
wa_10 = [0.007421, 0.011449, 0.023207, 0.086088, 0.180334]
wa_20 = [0.013384, 0.021687, 0.061213, 0.159714, 0.289025]
slateq = [0.064939, 0.110338, 0.229349, 0.448962, 1.150223]

# Create a dictionary to store the data
data = {'Wa_5': wa_5, 'Wa_10': wa_10, 'Wa_20': wa_20, 'Slateq': slateq}

# Convert the dictionary to a pandas DataFrame
df = pd.DataFrame(data=data, index=x)

# Set the color palette
colors = sns.color_palette('husl', 4)

# Create the bar plot
ax = sns.barplot(data=df, palette=colors)

# Set the title and axis labels
ax.set_title('comparison in serving time')
ax.set_xlabel('number of candidate items')
ax.set_ylabel('seconds')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis values
x = [300, 500, 1000, 2000, 50000]

# Define y-axis values
wa_5 = [0.004210, 0.006127, 0.011299, 0.042985, 0.093208]
wa_10 = [0.007421, 0.011449, 0.023207, 0.086088, 0.180334]
wa_20 = [0.013384, 0.021687, 0.061213, 0.159714, 0.289025]
slateq = [0.064939, 0.110338, 0.229349, 0.448962, 1.150223]

# Set the figure size and dpi
fig = plt.figure(figsize=(8, 6), dpi=300)

# Set the font size
plt.rcParams.update({'font.size': 12})

# Set the width of the bars
bar_width = 0.2

# Set the positions of the bars on the x-axis
r1 = [0, 1, 2, 3, 4]
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Create the bar plot
plt.bar(r1, wa_5, color='#1f77b4', width=bar_width, edgecolor='black', label='Wa_5')
plt.bar(r2, wa_10, color='#ff7f0e', width=bar_width, edgecolor='black', label='Wa_10')
plt.bar(r3, wa_20, color='#2ca02c', width=bar_width, edgecolor='black', label='Wa_20')
plt.bar(r4, slateq, color='#d62728', width=bar_width, edgecolor='black', label='Slateq')

# Add x-axis ticks and labels
plt.xticks([r + bar_width*1.5 for r in range(len(wa_5))], x)

# Add a legend
plt.legend()

# Set the title and axis labels
plt.title('Comparison in serving time for single user')
plt.xlabel('Number of candidates')
plt.ylabel('Time in seconds')

# Save the plot as a PDF file
plt.savefig('bar_plot.pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis values
x = [300, 500, 1000, 2000, 50000]

# Define y-axis values
wa_5 = [0.004210, 0.006127, 0.011299, 0.042985, 0.093208]
wa_10 = [0.007421, 0.011449, 0.023207, 0.086088, 0.180334]
wa_20 = [0.013384, 0.021687, 0.061213, 0.159714, 0.289025]
slateq = [0.064939, 0.110338, 0.229349, 0.448962, 1.150223]

# Set the figure size and dpi
fig = plt.figure(figsize=(8, 6), dpi=300)

# Set the font size
plt.rcParams.update({'font.size': 12})

# Set the width of the bars
bar_width = 0.2

# Set the positions of the bars on the x-axis
r1 = [0, 1, 2, 3, 4]
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Create the bar plot
plt.bar(r1, wa_5, color='#1f77b4', width=bar_width, edgecolor='black', label='Wa_5')
plt.bar(r2, wa_10, color='#ff7f0e', width=bar_width, edgecolor='black', label='Wa_10')
plt.bar(r3, wa_20, color='#2ca02c', width=bar_width, edgecolor='black', label='Wa_20')
plt.bar(r4, slateq, color='#d62728', width=bar_width, edgecolor='black', label='Slateq')

# Add x-axis ticks and labels
plt.xticks([r + bar_width*1.5 for r in range(len(wa_5))], x)

# Add a legend
plt.legend()

# Set the title and axis labels
plt.title('Bar Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Add the value at the top of each bar
for i, v in enumerate(wa_5):
    plt.text(i - 0.1, v + 0.01, str(round(v, 4)), color='black', fontweight='bold')
for i, v in enumerate(wa_10):
    plt.text(i + 0.1, v + 0.01, str(round(v, 4)), color='black', fontweight='bold')
for i, v in enumerate(wa_20):
    plt.text(i + 0.3, v + 0.01, str(round(v, 4)), color='black', fontweight='bold')
for i, v in enumerate(slateq):
    plt.text(i + 0.5, v + 0.01, str(round(v, 4)), color='black', fontweight='bold')

# Add the percentage from the minimum value for each x-axis value
for i in range(len(x)):
    min_val = min([wa_5[i], wa_10[i], wa_20[i], slateq[i]])
    plt.text(i + 0.1, min_val - 0.05, str(round((wa_5[i] - min_val) / min_val * 100, 2)) + '%', color='black', fontweight='bold')
    plt.text(i + 0.3, min_val - 0.05, str(round((wa_10[i] - min_val) / min_val * 100, 2)) + '%', color='black', fontweight='bold')
    plt.text(i + 0.5, min_val - 0.05, str(round((wa_20[i] - min_val) / min_val * 100, 2)) + '%', color='black', fontweight='bold')
    plt.text(i + 0.7, min_val - 0.05, str(round((slateq[i] - min_val) / min_val * 100, 2)) + '%', color='black', fontweight='bold')

# Save the plot as a PDF file
plt.savefig('bar_plot.pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis values
x = [300, 500, 1000, 2000, 50000]

# Define y-axis values
wa_5 = [0.004210, 0.006127, 0.011299, 0.042985, 0.093208]
wa_10 = [0.007421, 0.011449, 0.023207, 0.086088, 0.180334]
wa_20 = [0.013384, 0.021687, 0.061213, 0.159714, 0.289025]
slateq = [0.064939, 0.110338, 0.229349, 0.448962, 1.150223]

# Set the figure size and dpi
fig = plt.figure(figsize=(8, 6), dpi=300)

# Set the font size
plt.rcParams.update({'font.size': 12})

# Set the width of the bars
bar_width = 0.2

# Set the positions of the bars on the x-axis
r1 = [0, 1, 2, 3, 4]
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Create the bar plot
plt.bar(r1, wa_5, color='#1f77b4', width=bar_width, edgecolor='black', label='Wa_5')
plt.bar(r2, wa_10, color='#ff7f0e', width=bar_width, edgecolor='black', label='Wa_10')
plt.bar(r3, wa_20, color='#2ca02c', width=bar_width, edgecolor='black', label='Wa_20')
plt.bar(r4, slateq, color='#d62728', width=bar_width, edgecolor='black', label='Slateq')

# Add x-axis ticks and labels
plt.xticks([r + bar_width*1.5 for r in range(len(wa_5))], x)

# Add a legend
plt.legend()

# Set the title and axis labels
plt.title('Bar Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Add the value at the top of each bar
for i, v in enumerate(wa_5):
    plt.text(i - 0.1, v + 0.01, str(round(v, 3)), color='black', fontweight='bold')
for i, v in enumerate(wa_10):
    plt.text(i + 0.1, v + 0.01, str(round(v, 3)), color='black', fontweight='bold')
for i, v in enumerate(wa_20):
    plt.text(i + 0.3, v + 0.01, str(round(v, 3)), color='black', fontweight='bold')
for i, v in enumerate(slateq):
    plt.text(i + 0.5, v + 0.01, str(round(v, 3)), color='black', fontweight='bold')

# Save the plot as a PDF file
plt.savefig('bar_plot.pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define x-axis values
x = [300, 500, 1000, 2000, 5000]

# Define y-axis values
wa_5 = [0.004210, 0.006127, 0.011299, 0.042985, 0.093208]
wa_10 = [0.007421, 0.011449, 0.023207, 0.086088, 0.180334]
wa_20 = [0.013384, 0.021687, 0.061213, 0.159714, 0.289025]
slateq = [0.064939, 0.110338, 0.229349, 0.448962, 1.150223]

# Set the figure size and dpi
fig = plt.figure(figsize=(8, 6), dpi=300)

# Set the font size
plt.rcParams.update({'font.size': 12})

# Set the width of the bars
bar_width = 0.2

# Set the positions of the bars on the x-axis
r1 = [0, 1, 2, 3, 4]
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Create the bar plot
plt.bar(r1, wa_5, color='#1f77b4', width=bar_width, edgecolor='black', label='Wa_5')
plt.bar(r2, wa_10, color='#ff7f0e', width=bar_width, edgecolor='black', label='Wa_10')
plt.bar(r3, wa_20, color='#2ca02c', width=bar_width, edgecolor='black', label='Wa_20')
plt.bar(r4, slateq, color='#d62728', width=bar_width, edgecolor='black', label='Slateq')

# Add x-axis ticks and labels
plt.xticks([r + bar_width*1.5 for r in range(len(wa_5))], x)

# Add a legend
plt.legend()

# Set the title and axis labels
plt.title('Comparison in serving time for single user')
plt.xlabel('Number of candidates')
plt.ylabel('Time in seconds')

# Add the value at the top of each bar
for i, v in enumerate(wa_5):
    plt.text(i - 0.1, v + 0.01, str(round(v, 3)), color='black', fontsize=6)
for i, v in enumerate(wa_10):
    plt.text(i + 0.1, v + 0.01, str(round(v, 3)), color='black', fontsize=6)
for i, v in enumerate(wa_20):
    plt.text(i + 0.3, v + 0.01, str(round(v, 3)), color='black', fontsize=6)
for i, v in enumerate(slateq):
    plt.text(i + 0.5, v + 0.01, str(round(v, 3)), color='black', fontsize=6)

# Save the plot as a PDF file
plt.savefig('bar_plot.pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np

# %%
# Define x-axis values
x = [300, 500, 1000, 2000]
num_candidates = [c for _ in range(4) for c in x]

# Define y-axis values
wa_5 = [0.004210, 0.006127, 0.011299, 0.042985]
wa_10 = [0.007421, 0.011449, 0.023207, 0.086088]
wa_20 = [0.013384, 0.021687, 0.061213, 0.159714]
slateq = [0.064939, 0.110338, 0.229349, 0.448962]

alg_names = ["slateq", "wa20", "wa10", "wa5"]
alg_name_col = [name for name in alg_names for _ in range(4)]
time = np.concatenate([slateq, wa_20, wa_10, wa_5])
res_df = pd.DataFrame({"serving time": time, "alg": alg_name_col, "num candidates":num_candidates})

# %%
# Set the plot style to "ticks"
sns.set_style("whitegrid", {"grid.linestyle": "--", "axes.edgecolor": "gray"})

# %%
figure(figsize=(8, 4), dpi=80)
sns.barplot(data=res_df, x="num candidates", y="serving time", hue="alg", hue_order=["wa5", "wa10", "wa20", "slateq"], palette=["red", "green", "orange", "blue"])
plt.ylabel("serving time (sec)")
plt.xlabel("number of candidates")
plt.legend(title="")
